# %%
import pyedflib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os
import re
import xml.etree.ElementTree as ET

# %%
# Maps
video_emotion_map = {
    '69.avi': 'disgust',
    '55.avi': 'anger',
    '58.avi': 'amusement',
    'earworm_f.avi': 'disgust',
    '53.avi': 'amusement',
    '80.avi': 'joy',
    '52.avi': 'amusement',
    '79.avi': 'joy',
    '73.avi': 'fear',
    '90.avi': 'joy',
    '107.avi': 'fear',
    '146.avi': 'sadness',
    '30.avi': 'fear',
    '138.avi': 'sadness',
    'newyork_f.avi': 'neutral',
    '111.avi': 'sadness',
    'detroit_f.avi': 'neutral',
    'cats_f.avi': 'joy',
    'dallas_f.avi': 'neutral',
    'funny_f.avi': 'joy'
}

emotion_number_map= {
    'neutral': 0,
    'anger': 1,
    'disgust': 2,
    'fear': 3,
    'joy': 4,
    'sadness': 5,
    'suprise': 6,
    'scream': 7,
    'bored': 8,
    'sleepy': 9,
    'unknown': 10,
    'amusement': 11,
    'anxiety': 12
}

# %%
# Read file names
dataset_root = '/Users/Russel/myProjects/emotion-recognition/code/datasets/mahnob_hci/Sessions/'
dataset_path = Path(dataset_root)
dataset_dirs = sorted(os.listdir(dataset_root), key=int)
dataset_dirs = [dataset_path / dataset_dir for dataset_dir in dataset_dirs]

dataset = []

bdf_file_pattern = re.compile('Part_(?P<subject>\d+)_S_Trial(?P<trial>\d+)_emotion')

for dataset_dir in dataset_dirs:
    bdf_file = list(dataset_dir.glob("*.bdf"))
    if bdf_file:
        bdf_file = bdf_file[0]
        print(bdf_file.stem)
        session_file = list(dataset_dir.glob("*.xml"))[0]
        
        # Read signal
        f = pyedflib.EdfReader(str(bdf_file))
        sigbufs = np.zeros((4, f.getNSamples()[0]))
        sigbufs[0, :] = f.readSignal(32)
        sigbufs[1, :] = f.readSignal(33)
        sigbufs[2, :] = f.readSignal(34)
        sigbufs[3, :] = f.readSignal(46)
            
        # Read metadata
        m = bdf_file_pattern.match(bdf_file.stem)
        subject = m.groups()[0]
        trial = m.groups()[1]
        
        # Read labels
        root = ET.parse(session_file).getroot()
        
        # Append to dataset dataframe
        dataset.append({
            'ECG1': sigbufs[0],
            'ECG2': sigbufs[1],
            'ECG3': sigbufs[2],
            'status': sigbufs[3],
            'label': [int(emotion_number_map[video_emotion_map[root.attrib['mediaFile']]])],
            'feltEmo': int(root.attrib['feltEmo']),
            'feltArsl': int(root.attrib['feltArsl']),
            'feltVlnc': int(root.attrib['feltVlnc']),
            'feltCtrl': int(root.attrib['feltCtrl']),
            'feltPred': int(root.attrib['feltPred'])
        })
len(dataset)
# Out:
# Part_1_S_Trial1_emotion
# Part_1_S_Trial2_emotion
# Part_1_S_Trial3_emotion
# Part_1_S_Trial4_emotion
# Part_1_S_Trial5_emotion
# Part_1_S_Trial6_emotion
# Part_1_S_Trial7_emotion
# Part_1_S_Trial8_emotion
# Part_1_S_Trial9_emotion
# Part_1_S_Trial10_emotion
# Part_1_S_Trial11_emotion
# Part_1_S_Trial12_emotion
# Part_1_S_Trial13_emotion
# Part_1_S_Trial14_emotion
# Part_1_S_Trial15_emotion
# Part_1_S_Trial16_emotion
# Part_1_S_Trial17_emotion
# Part_1_S_Trial18_emotion
# Part_1_S_Trial19_emotion
# Part_1_S_Trial20_emotion
# Part_2_S_Trial1_emotion
# Part_2_S_Trial2_emotion
# Part_2_S_Trial3_emotion
# Part_2_S_Trial4_emotion
# Part_2_S_Trial5_emotion
# Part_2_S_Trial6_emotion
# Part_2_S_Trial7_emotion
# Part_2_S_Trial8_emotion
# Part_2_S_Trial9_emotion
# Part_2_S_Trial10_emotion
# Part_2_S_Trial11_emotion
# Part_2_S_Trial12_emotion
# Part_2_S_Trial13_emotion
# Part_2_S_Trial14_emotion
# Part_2_S_Trial15_emotion
# Part_2_S_Trial16_emotion
# Part_2_S_Trial17_emotion
# Part_2_S_Trial18_emotion
# Part_2_S_Trial19_emotion
# Part_2_S_Trial20_emotion
# Part_3_S_Trial1_emotion
# Part_3_S_Trial2_emotion
# Part_3_S_Trial3_emotion
# Part_3_S_Trial4_emotion
# Part_3_S_Trial5_emotion
# Part_3_S_Trial6_emotion
# Part_3_S_Trial7_emotion
# Part_3_S_Trial8_emotion
# Part_3_S_Trial9_emotion
# Part_3_S_Trial10_emotion
# Part_3_S_Trial11_emotion
# Part_3_S_Trial12_emotion
# Part_3_S_Trial13_emotion
# Part_3_S_Trial14_emotion
# Part_3_S_Trial15_emotion
# Part_3_S_Trial16_emotion
# Part_3_S_Trial17_emotion
# Part_4_S_Trial1_emotion
# Part_4_S_Trial2_emotion
# Part_4_S_Trial3_emotion
# Part_4_S_Trial4_emotion
# Part_4_S_Trial5_emotion
# Part_4_S_Trial6_emotion
# Part_4_S_Trial7_emotion
# Part_4_S_Trial8_emotion
# Part_4_S_Trial9_emotion
# Part_4_S_Trial10_emotion
# Part_4_S_Trial11_emotion
# Part_4_S_Trial12_emotion
# Part_4_S_Trial13_emotion
# Part_4_S_Trial14_emotion
# Part_4_S_Trial15_emotion
# Part_4_S_Trial16_emotion
# Part_4_S_Trial17_emotion
# Part_4_S_Trial18_emotion
# Part_4_S_Trial19_emotion
# Part_4_S_Trial20_emotion
# Part_5_S_Trial1_emotion
# Part_5_S_Trial2_emotion
# Part_5_S_Trial3_emotion
# Part_5_S_Trial4_emotion
# Part_5_S_Trial5_emotion
# Part_5_S_Trial6_emotion
# Part_5_S_Trial7_emotion
# Part_5_S_Trial8_emotion
# Part_5_S_Trial9_emotion
# Part_5_S_Trial10_emotion
# Part_5_S_Trial11_emotion
# Part_5_S_Trial12_emotion
# Part_5_S_Trial13_emotion
# Part_5_S_Trial14_emotion
# Part_5_S_Trial15_emotion
# Part_5_S_Trial16_emotion
# Part_5_S_Trial17_emotion
# Part_5_S_Trial18_emotion
# Part_5_S_Trial19_emotion
# Part_5_S_Trial20_emotion
# Part_6_S_Trial1_emotion
# Part_6_S_Trial2_emotion
# Part_6_S_Trial3_emotion
# Part_6_S_Trial4_emotion
# Part_6_S_Trial5_emotion
# Part_6_S_Trial6_emotion
# Part_6_S_Trial7_emotion
# Part_6_S_Trial8_emotion
# Part_6_S_Trial9_emotion
# Part_6_S_Trial10_emotion
# Part_6_S_Trial11_emotion
# Part_6_S_Trial12_emotion
# Part_6_S_Trial13_emotion
# Part_6_S_Trial14_emotion
# Part_6_S_Trial15_emotion
# Part_6_S_Trial16_emotion
# Part_6_S_Trial17_emotion
# Part_6_S_Trial18_emotion
# Part_6_S_Trial19_emotion
# Part_6_S_Trial20_emotion
# Part_7_S_Trial1_emotion
# Part_7_S_Trial2_emotion
# Part_7_S_Trial3_emotion
# Part_7_S_Trial4_emotion
# Part_7_S_Trial5_emotion
# Part_7_S_Trial6_emotion
# Part_7_S_Trial7_emotion
# Part_7_S_Trial8_emotion
# Part_7_S_Trial9_emotion
# Part_7_S_Trial10_emotion
# Part_7_S_Trial11_emotion
# Part_7_S_Trial12_emotion
# Part_7_S_Trial13_emotion
# Part_7_S_Trial14_emotion
# Part_7_S_Trial15_emotion
# Part_7_S_Trial16_emotion
# Part_7_S_Trial17_emotion
# Part_7_S_Trial18_emotion
# Part_7_S_Trial19_emotion
# Part_7_S_Trial20_emotion
# Part_8_S_Trial1_emotion
# Part_8_S_Trial2_emotion
# Part_8_S_Trial3_emotion
# Part_8_S_Trial4_emotion
# Part_8_S_Trial5_emotion
# Part_8_S_Trial6_emotion
# Part_8_S_Trial7_emotion
# Part_8_S_Trial8_emotion
# Part_8_S_Trial9_emotion
# Part_8_S_Trial10_emotion
# Part_8_S_Trial11_emotion
# Part_8_S_Trial12_emotion
# Part_8_S_Trial13_emotion
# Part_8_S_Trial14_emotion
# Part_8_S_Trial15_emotion
# Part_8_S_Trial16_emotion
# Part_8_S_Trial17_emotion
# Part_8_S_Trial18_emotion
# Part_8_S_Trial19_emotion
# Part_8_S_Trial20_emotion
# Part_9_S_Trial1_emotion
# Part_9_S_Trial2_emotion
# Part_9_S_Trial3_emotion
# Part_9_S_Trial4_emotion
# Part_9_S_Trial5_emotion
# Part_9_S_Trial6_emotion
# Part_9_S_Trial7_emotion
# Part_9_S_Trial8_emotion
# Part_9_S_Trial9_emotion
# Part_9_S_Trial10_emotion
# Part_9_S_Trial11_emotion
# Part_9_S_Trial12_emotion
# Part_9_S_Trial13_emotion
# Part_9_S_Trial14_emotion
# Part_10_S_Trial1_emotion
# Part_10_S_Trial2_emotion
# Part_10_S_Trial3_emotion
# Part_10_S_Trial4_emotion
# Part_10_S_Trial5_emotion
# Part_10_S_Trial6_emotion
# Part_10_S_Trial7_emotion
# Part_10_S_Trial8_emotion
# Part_10_S_Trial9_emotion
# Part_10_S_Trial10_emotion
# Part_10_S_Trial11_emotion
# Part_10_S_Trial12_emotion
# Part_10_S_Trial13_emotion
# Part_10_S_Trial14_emotion
# Part_10_S_Trial15_emotion
# Part_10_S_Trial16_emotion
# Part_10_S_Trial17_emotion
# Part_10_S_Trial18_emotion
# Part_10_S_Trial19_emotion
# Part_10_S_Trial20_emotion
# Part_11_S_Trial1_emotion
# Part_11_S_Trial2_emotion
# Part_11_S_Trial3_emotion
# Part_11_S_Trial4_emotion
# Part_11_S_Trial5_emotion
# Part_11_S_Trial6_emotion
# Part_11_S_Trial7_emotion
# Part_11_S_Trial8_emotion
# Part_11_S_Trial9_emotion
# Part_11_S_Trial10_emotion
# Part_11_S_Trial11_emotion
# Part_11_S_Trial12_emotion
# Part_11_S_Trial13_emotion
# Part_11_S_Trial14_emotion
# Part_11_S_Trial15_emotion
# Part_11_S_Trial16_emotion
# Part_11_S_Trial17_emotion
# Part_11_S_Trial18_emotion
# Part_11_S_Trial19_emotion
# Part_11_S_Trial20_emotion
# Part_13_S_Trial1_emotion
# Part_13_S_Trial2_emotion
# Part_13_S_Trial3_emotion
# Part_13_S_Trial4_emotion
# Part_13_S_Trial5_emotion
# Part_13_S_Trial6_emotion
# Part_13_S_Trial7_emotion
# Part_13_S_Trial8_emotion
# Part_13_S_Trial9_emotion
# Part_13_S_Trial10_emotion
# Part_13_S_Trial11_emotion
# Part_13_S_Trial12_emotion
# Part_13_S_Trial13_emotion
# Part_13_S_Trial14_emotion
# Part_13_S_Trial15_emotion
# Part_13_S_Trial16_emotion
# Part_13_S_Trial17_emotion
# Part_13_S_Trial18_emotion
# Part_13_S_Trial19_emotion
# Part_13_S_Trial20_emotion
# Part_14_S_Trial1_emotion
# Part_14_S_Trial2_emotion
# Part_14_S_Trial3_emotion
# Part_14_S_Trial4_emotion
# Part_14_S_Trial5_emotion
# Part_14_S_Trial6_emotion
# Part_14_S_Trial7_emotion
# Part_14_S_Trial8_emotion
# Part_14_S_Trial9_emotion
# Part_14_S_Trial10_emotion
# Part_14_S_Trial11_emotion
# Part_14_S_Trial12_emotion
# Part_14_S_Trial13_emotion
# Part_14_S_Trial14_emotion
# Part_14_S_Trial15_emotion
# Part_14_S_Trial16_emotion
# Part_14_S_Trial17_emotion
# Part_14_S_Trial18_emotion
# Part_14_S_Trial19_emotion
# Part_14_S_Trial20_emotion
# Part_16_S_Trial1_emotion
# Part_16_S_Trial2_emotion
# Part_16_S_Trial3_emotion
# Part_16_S_Trial4_emotion
# Part_16_S_Trial5_emotion
# Part_16_S_Trial6_emotion
# Part_16_S_Trial7_emotion
# Part_16_S_Trial8_emotion
# Part_16_S_Trial9_emotion
# Part_16_S_Trial10_emotion
# Part_16_S_Trial11_emotion
# Part_16_S_Trial12_emotion
# Part_16_S_Trial13_emotion
# Part_16_S_Trial14_emotion
# Part_16_S_Trial15_emotion
# Part_16_S_Trial16_emotion
# Part_17_S_Trial1_emotion
# Part_17_S_Trial2_emotion
# Part_17_S_Trial3_emotion
# Part_17_S_Trial4_emotion
# Part_17_S_Trial5_emotion
# Part_17_S_Trial6_emotion
# Part_17_S_Trial7_emotion
# Part_17_S_Trial8_emotion
# Part_17_S_Trial9_emotion
# Part_17_S_Trial10_emotion
# Part_17_S_Trial11_emotion
# Part_17_S_Trial12_emotion
# Part_17_S_Trial13_emotion
# Part_17_S_Trial14_emotion
# Part_17_S_Trial15_emotion
# Part_17_S_Trial16_emotion
# Part_17_S_Trial17_emotion
# Part_17_S_Trial18_emotion
# Part_17_S_Trial19_emotion
# Part_17_S_Trial20_emotion
# Part_18_S_Trial1_emotion
# Part_18_S_Trial2_emotion
# Part_18_S_Trial3_emotion
# Part_18_S_Trial4_emotion
# Part_18_S_Trial5_emotion
# Part_18_S_Trial6_emotion
# Part_18_S_Trial7_emotion
# Part_18_S_Trial8_emotion
# Part_18_S_Trial9_emotion
# Part_18_S_Trial10_emotion
# Part_18_S_Trial11_emotion
# Part_18_S_Trial12_emotion
# Part_18_S_Trial13_emotion
# Part_18_S_Trial14_emotion
# Part_18_S_Trial15_emotion
# Part_18_S_Trial16_emotion
# Part_18_S_Trial17_emotion
# Part_18_S_Trial18_emotion
# Part_18_S_Trial19_emotion
# Part_18_S_Trial20_emotion
# Part_19_S_Trial1_emotion
# Part_19_S_Trial2_emotion
# Part_19_S_Trial3_emotion
# Part_19_S_Trial4_emotion
# Part_19_S_Trial5_emotion
# Part_19_S_Trial6_emotion
# Part_19_S_Trial7_emotion
# Part_19_S_Trial8_emotion
# Part_19_S_Trial9_emotion
# Part_19_S_Trial10_emotion
# Part_19_S_Trial11_emotion
# Part_19_S_Trial12_emotion
# Part_19_S_Trial13_emotion
# Part_19_S_Trial14_emotion
# Part_19_S_Trial15_emotion
# Part_19_S_Trial16_emotion
# Part_19_S_Trial17_emotion
# Part_19_S_Trial18_emotion
# Part_19_S_Trial19_emotion
# Part_19_S_Trial20_emotion
# Part_20_S_Trial1_emotion
# Part_20_S_Trial2_emotion
# Part_20_S_Trial3_emotion
# Part_20_S_Trial4_emotion
# Part_20_S_Trial5_emotion
# Part_20_S_Trial6_emotion
# Part_20_S_Trial7_emotion
# Part_20_S_Trial8_emotion
# Part_20_S_Trial9_emotion
# Part_20_S_Trial10_emotion
# Part_20_S_Trial11_emotion
# Part_20_S_Trial12_emotion
# Part_20_S_Trial13_emotion
# Part_20_S_Trial14_emotion
# Part_20_S_Trial15_emotion
# Part_20_S_Trial16_emotion
# Part_20_S_Trial17_emotion
# Part_20_S_Trial18_emotion
# Part_20_S_Trial19_emotion
# Part_20_S_Trial20_emotion
# Part_21_S_Trial1_emotion
# Part_21_S_Trial2_emotion
# Part_21_S_Trial3_emotion
# Part_21_S_Trial4_emotion
# Part_21_S_Trial5_emotion
# Part_21_S_Trial6_emotion
# Part_21_S_Trial7_emotion
# Part_21_S_Trial8_emotion
# Part_21_S_Trial9_emotion
# Part_21_S_Trial10_emotion
# Part_21_S_Trial11_emotion
# Part_21_S_Trial12_emotion
# Part_21_S_Trial13_emotion
# Part_21_S_Trial14_emotion
# Part_21_S_Trial15_emotion
# Part_21_S_Trial16_emotion
# Part_21_S_Trial17_emotion
# Part_21_S_Trial18_emotion
# Part_21_S_Trial19_emotion
# Part_21_S_Trial20_emotion
# Part_22_S_Trial1_emotion
# Part_22_S_Trial2_emotion
# Part_22_S_Trial3_emotion
# Part_22_S_Trial4_emotion
# Part_22_S_Trial5_emotion
# Part_22_S_Trial6_emotion
# Part_22_S_Trial7_emotion
# Part_22_S_Trial8_emotion
# Part_22_S_Trial9_emotion
# Part_22_S_Trial10_emotion
# Part_22_S_Trial11_emotion
# Part_22_S_Trial12_emotion
# Part_22_S_Trial13_emotion
# Part_22_S_Trial14_emotion
# Part_22_S_Trial15_emotion
# Part_22_S_Trial16_emotion
# Part_22_S_Trial17_emotion
# Part_22_S_Trial18_emotion
# Part_22_S_Trial19_emotion
# Part_22_S_Trial20_emotion
# Part_23_S_Trial1_emotion
# Part_23_S_Trial2_emotion
# Part_23_S_Trial3_emotion
# Part_23_S_Trial4_emotion
# Part_23_S_Trial5_emotion
# Part_23_S_Trial6_emotion
# Part_23_S_Trial7_emotion
# Part_23_S_Trial8_emotion
# Part_23_S_Trial9_emotion
# Part_23_S_Trial10_emotion
# Part_23_S_Trial11_emotion
# Part_23_S_Trial12_emotion
# Part_23_S_Trial13_emotion
# Part_23_S_Trial14_emotion
# Part_23_S_Trial15_emotion
# Part_23_S_Trial16_emotion
# Part_23_S_Trial17_emotion
# Part_23_S_Trial18_emotion
# Part_23_S_Trial19_emotion
# Part_23_S_Trial20_emotion
# Part_24_S_Trial1_emotion
# Part_24_S_Trial2_emotion
# Part_24_S_Trial3_emotion
# Part_24_S_Trial4_emotion
# Part_24_S_Trial5_emotion
# Part_24_S_Trial6_emotion
# Part_24_S_Trial7_emotion
# Part_24_S_Trial8_emotion
# Part_24_S_Trial9_emotion
# Part_24_S_Trial10_emotion
# Part_24_S_Trial11_emotion
# Part_24_S_Trial12_emotion
# Part_24_S_Trial13_emotion
# Part_24_S_Trial14_emotion
# Part_24_S_Trial15_emotion
# Part_24_S_Trial16_emotion
# Part_24_S_Trial17_emotion
# Part_24_S_Trial18_emotion
# Part_24_S_Trial19_emotion
# Part_24_S_Trial20_emotion
# Part_25_S_Trial1_emotion
# Part_25_S_Trial2_emotion
# Part_25_S_Trial3_emotion
# Part_25_S_Trial4_emotion
# Part_25_S_Trial5_emotion
# Part_25_S_Trial6_emotion
# Part_25_S_Trial7_emotion
# Part_25_S_Trial8_emotion
# Part_25_S_Trial9_emotion
# Part_25_S_Trial10_emotion
# Part_25_S_Trial11_emotion
# Part_25_S_Trial12_emotion
# Part_25_S_Trial13_emotion
# Part_25_S_Trial14_emotion
# Part_25_S_Trial15_emotion
# Part_25_S_Trial16_emotion
# Part_25_S_Trial17_emotion
# Part_25_S_Trial18_emotion
# Part_25_S_Trial19_emotion
# Part_25_S_Trial20_emotion
# Part_27_S_Trial1_emotion
# Part_27_S_Trial2_emotion
# Part_27_S_Trial3_emotion
# Part_27_S_Trial4_emotion
# Part_27_S_Trial5_emotion
# Part_27_S_Trial6_emotion
# Part_27_S_Trial7_emotion
# Part_27_S_Trial8_emotion
# Part_27_S_Trial9_emotion
# Part_27_S_Trial10_emotion
# Part_27_S_Trial11_emotion
# Part_27_S_Trial12_emotion
# Part_27_S_Trial13_emotion
# Part_27_S_Trial14_emotion
# Part_27_S_Trial15_emotion
# Part_27_S_Trial16_emotion
# Part_27_S_Trial17_emotion
# Part_27_S_Trial18_emotion
# Part_27_S_Trial19_emotion
# Part_27_S_Trial20_emotion
# Part_28_S_Trial1_emotion
# Part_28_S_Trial2_emotion
# Part_28_S_Trial3_emotion
# Part_28_S_Trial4_emotion
# Part_28_S_Trial5_emotion
# Part_28_S_Trial6_emotion
# Part_28_S_Trial7_emotion
# Part_28_S_Trial8_emotion
# Part_28_S_Trial9_emotion
# Part_28_S_Trial10_emotion
# Part_28_S_Trial11_emotion
# Part_28_S_Trial12_emotion
# Part_28_S_Trial13_emotion
# Part_28_S_Trial14_emotion
# Part_28_S_Trial15_emotion
# Part_28_S_Trial16_emotion
# Part_28_S_Trial17_emotion
# Part_28_S_Trial18_emotion
# Part_28_S_Trial19_emotion
# Part_28_S_Trial20_emotion
# Part_29_S_Trial1_emotion
# Part_29_S_Trial2_emotion
# Part_29_S_Trial3_emotion
# Part_29_S_Trial4_emotion
# Part_29_S_Trial5_emotion
# Part_29_S_Trial6_emotion
# Part_29_S_Trial7_emotion
# Part_29_S_Trial8_emotion
# Part_29_S_Trial9_emotion
# Part_29_S_Trial10_emotion
# Part_29_S_Trial11_emotion
# Part_29_S_Trial12_emotion
# Part_29_S_Trial13_emotion
# Part_29_S_Trial14_emotion
# Part_29_S_Trial15_emotion
# Part_29_S_Trial16_emotion
# Part_29_S_Trial17_emotion
# Part_29_S_Trial18_emotion
# Part_29_S_Trial19_emotion
# Part_29_S_Trial20_emotion
# Part_30_S_Trial1_emotion
# Part_30_S_Trial2_emotion
# Part_30_S_Trial3_emotion
# Part_30_S_Trial4_emotion
# Part_30_S_Trial5_emotion
# Part_30_S_Trial6_emotion
# Part_30_S_Trial7_emotion
# Part_30_S_Trial8_emotion
# Part_30_S_Trial9_emotion
# Part_30_S_Trial10_emotion
# Part_30_S_Trial11_emotion
# Part_30_S_Trial12_emotion
# Part_30_S_Trial13_emotion
# Part_30_S_Trial14_emotion
# Part_30_S_Trial15_emotion
# Part_30_S_Trial16_emotion
# Part_30_S_Trial17_emotion
# Part_30_S_Trial18_emotion
# Part_30_S_Trial19_emotion
# Part_30_S_Trial20_emotion
# 527

# %%
st = dataset[0]['status']
